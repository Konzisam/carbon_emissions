# %%
import pandas as pd
import numpy as np
from time import time

# %%
from google.cloud import bigquery
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_5290/3552294376.py in <module>
# ----> 1 from google.cloud import bigquery
#
# ModuleNotFoundError: No module named 'google'

# %%
# Load data to a pandas dataframe
df = pd.read_csv('df_chunk1.csv')

# Visualize top two records
df.head(5)
# Out:
#    Unnamed: 0        ID Country    Vehicle_Family_ID  \
# 0           0  57566673      IS  IP-01-JMB-2018-0001
# 1           1  57566674      IS  IP-01-JMB-2018-0001
# 2           2  57566675      IS  IP-01-JMB-2018-0001
# 3           3  57566676      IS  IP-01-JMB-2018-0001
# 4           4  57566677      IS  IP-01-JMB-2018-0001
#
#                         Pool                Manufacturer_EU  \
# 0  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS CORPORATION
# 1  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS CORPORATION
# 2  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS CORPORATION
# 3  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS CORPORATION
# 4  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS CORPORATION
#
#                 Manufacturer_OEM  Manufacturer_MS            TA_number Type  \
# 0  MITSUBISHI MOTORS CORPORATION              NaN  E1*2001/116*0406*32  CW0
# 1  MITSUBISHI MOTORS CORPORATION              NaN  E1*2001/116*0406*32  CW0
# ...

# %%
#df.drop(columns='Unnamed: 0',inplace=True)

# %%
df.columns
# Out:
# Index(['ID', 'Country', 'Vehicle_Family_ID', 'Pool', 'Manufacturer_EU',
#        'Manufacturer_OEM', 'Manufacturer_MS', 'TA_number', 'Type', 'Variant',
#        'Version', 'Make', 'Commercial_Name', 'Category_A', 'Category_R',
#        'Total_registrations', 'Mass_RO', 'WLTP_test_mass', 'Emissions_NEDC',
#        'Emissions_WLTP', 'Wheel_base', 'Axle_width_steering',
#        'Axle_width_other', 'Fuel_type', 'Fuel_mode', 'Engine_capacity',
#        'Engine_power', 'Electricity_consumption', 'Emission_reduction_IT',
#        'Emission_reduction_NEDC', 'Emission_reduction_WLTP',
#        'Deviation_factor', 'Verification_factor', 'Type_of_data',
#        'Registration_year', 'Registration_date', 'Fuel_consumption',
#        'Electric_range'],
#       dtype='object')

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/carbon')

# %%
# %load_ext sql_magic
# %config SQL.conn_name = 'engine'

# %%
print(pd.io.sql.get_schema(df, name='carbon', con=engine))
# Out:
# CREATE TABLE carbon (
# 	"ID" BIGINT,
# 	"Country" TEXT,
# 	"Vehicle_Family_ID" TEXT,
# 	"Pool" TEXT,
# 	"Manufacturer_EU" TEXT,
# 	"Manufacturer_OEM" TEXT,
# 	"Manufacturer_MS" FLOAT(53),
# 	"TA_number" TEXT,
# 	"Type" TEXT,
# 	"Variant" TEXT,
# 	"Version" TEXT,
# 	"Make" TEXT,
# 	"Commercial_Name" TEXT,
# 	"Category_A" TEXT,
# 	"Category_R" TEXT,
# 	"Total_registrations" BIGINT,
# 	"Mass_RO" FLOAT(53),
# 	"WLTP_test_mass" FLOAT(53),
# 	"Emissions_NEDC" FLOAT(53),
# 	"Emissions_WLTP" FLOAT(53),
# 	"Wheel_base" FLOAT(53),
# 	"Axle_width_steering" FLOAT(53),
# 	"Axle_width_other" FLOAT(53),
# 	"Fuel_type" TEXT,
# 	"Fuel_mode" TEXT,
# 	"Engine_capacity" FLOAT(53),
# 	"Engine_power" FLOAT(53),
# 	"Electricity_consumption" FLOAT(53),
# 	"Emission_reduction_IT" TEXT,
# 	"Emission_reduction_NEDC" FLOAT(53),
# 	"Emission_reduction_WLTP" FLOAT(53),
# 	"Deviation_factor" FLOAT(53),
# 	"Verification_factor" FLOAT(53),
# 	"Type_of_data" TEXT,
# 	"Registration_year" BIGINT,
# ...

# %%
#Create table and specify columns
df.head(n=0).to_sql(name='emissions', con=engine, if_exists='replace')
# Out:
# 0

# %%
df['Registration_date'] = pd.to_datetime(df['Registration_date'])

# %%
df.to_sql(name='emissions', con=engine, if_exists='append')
# Out:
# 1000

# %%
# %%read_sql df_result
#
# select * from emissions where "Vehicle_Family_ID" is null
# Out:
# Query started at 03:07:11 PM UTC; Query executed in 0.00 m
#       index        ID Country Vehicle_Family_ID           Pool  \
# 0       151  57566824      IS              None  MERCEDES-BENZ
# 1       153  57566826      IS              None  MERCEDES-BENZ
# 2       156  57566829      IS              None  MERCEDES-BENZ
# 3       158  57566831      IS              None  MERCEDES-BENZ
# 4       159  57566832      IS              None  MERCEDES-BENZ
# ...     ...       ...     ...               ...            ...
# 3018  99866  56658952      BE              None        VW-SAIC
# 3019  99883  56658969      BE              None        VW-SAIC
# 3020  99921  56659007      BE              None        VW-SAIC
# 3021  99935  56659021      BE              None        VW-SAIC
# 3022  99999  56659085      BE              None     STELLANTIS
#
#        Manufacturer_EU  Manufacturer_OEM Manufacturer_MS            TA_number  \
# ...

# %%
#read data iteratively with 200k chunks
df_iter = pd.read_csv('data.csv', iterator=True, chunksize=200000)

# %%
while True: 

    try:
        t_start = time()

        df = next(df_iter)
        
        df.rename(columns=cols, inplace =True)
        df['Registration_date'] = pd.to_datetime(df['Registration_date']) 
               

        df.to_sql(name='emissions', con=engine, if_exists='append')

        t_end = time()

        print('inserted another chunk, took %.3f second' % (t_end - t_start))

    except StopIteration:
        print("Finished ingesting data into the postgres database")
        break
# Out:
# ---------------------------------------------------------------------------
# InvalidTextRepresentation                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1798                 if not evt_handled:
# -> 1799                     self.dialect.do_executemany(
#    1800                         cursor, statement, parameters, context
#
# ~/anaconda3/lib/python3.9/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     952             xtras = self._psycopg2_extras()
# --> 953             context._psycopg2_fetched_rows = xtras.execute_values(
#     954                 cursor,
#
# ~/anaconda3/lib/python3.9/site-packages/psycopg2/extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1298         parts[-1:] = post
# ...
